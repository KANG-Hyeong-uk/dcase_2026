# %% [markdown]
# # 5-17 regression confidence -> DCASE baseline
#
# This notebook loads `outputs/confidence_regression_outputs/C_audio_text_class_dropout_0.5_model.pt`, predicts continuous confidence scores only for `train_pool`, and trains downstream baseline models on predicted confidence `>= 2`, `>= 3`, and `>= 4`.
#
# The fixed `final_test 20%` is never scored or filtered.

# %%
from pathlib import Path
import sys

HERE = Path.cwd()
if not (HERE / 'confidence_baseline_common.py').exists():
    sys.path.insert(0, str(HERE / 'baseline_confidnce_train'))
else:
    sys.path.insert(0, str(HERE))

from confidence_baseline_common import (
    ROOT,
    load_baseline_assets,
    make_fixed_holdout,
    load_517_regression_scores,
    run_downstream_grid,
    confidence_threshold_specs,
)

SEED = 1821
BASELINE_MODES = ('both',)
USE_KFOLD = True
N_FOLDS = 5
NUM_EPOCHS = 100
BATCH_SIZE = 64

full_df, _, _ = load_baseline_assets(ROOT)
tmp_out = ROOT / 'baseline_confidnce_train' / 'outputs' / '517_regression'
train_pool, final_test, _ = make_fixed_holdout(full_df, tmp_out, seed=SEED)
score_df = load_517_regression_scores(train_pool, ROOT)
score_df.head()
# Out:
# [517 regression] loading features 1/8,764 | kept=0 | skipped=0
# [517 regression] loading features 1,000/8,764 | kept=999 | skipped=0
# [517 regression] loading features 2,000/8,764 | kept=1,999 | skipped=0
# [517 regression] loading features 3,000/8,764 | kept=2,999 | skipped=0
# [517 regression] loading features 4,000/8,764 | kept=3,999 | skipped=0
# [517 regression] loading features 5,000/8,764 | kept=4,999 | skipped=0
# [517 regression] loading features 6,000/8,764 | kept=5,999 | skipped=0
# [517 regression] loading features 7,000/8,764 | kept=6,999 | skipped=0
# [517 regression] loading features 8,000/8,764 | kept=7,999 | skipped=0
# [517 regression] loading features 8,764/8,764 | kept=8,763 | skipped=0
# [517 regression] inference device: cuda
# [517 regression] saved scores: c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\train_pool_regression_scores.csv
#   sound_id  predicted_confidence_score
# 0   185755                    3.177689
# 1   432206                    3.380891
# 2    80630                    3.806050
# 3   145544                    3.759196
# 4   156796                    3.501560

# %%
summary, filter_counts = run_downstream_grid(
    experiment_name='517_regression_continuous_score',
    score_df=score_df,
    output_root=ROOT / 'baseline_confidnce_train' / 'outputs' / '517_regression',
    score_col='predicted_confidence_score',
    threshold_specs=confidence_threshold_specs([2, 3, 4]),
    baseline_modes=BASELINE_MODES,
    use_kfold=USE_KFOLD,
    n_folds=N_FOLDS,
    seed=SEED,
    missing_score_policy='drop',
    num_epochs=NUM_EPOCHS,
    batch_size=BATCH_SIZE,
)
display(filter_counts)
summary
# Out:
# === Filter counts ===
# filter_label               score_column  threshold  display_threshold  train_pool_samples  retained_samples  dropped_samples  retained_ratio  num_classes_retained
#    pred_ge_2 predicted_confidence_score        2.0                  2                8764              8763                1        0.999886                    23
#    pred_ge_3 predicted_confidence_score        3.0                  3                8764              8155              609        0.930511                    23
#    pred_ge_4 predicted_confidence_score        4.0                  4                8764              1289             7475        0.147079                    19
#
# === Downstream baseline plan ===
# experiment=517_regression_continuous_score
# device=cuda:0 (NVIDIA GeForce RTX 3060, 8.6 GB)
# baseline_modes=('both',)
# use_kfold=True, n_folds=5
# thresholds=[2, 3, 4]
# planned_trainings=15
# num_epochs=100, batch_size=64
#
# [run] c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_2\both\fold_0
#   device=cuda:0 (NVIDIA GeForce RTX 3060, 8.6 GB)
#   samples: train=7010, val=1753, final_test=2192
#   batches: train=109, val=28, test=35
#   max_epochs=100, batch_size=64
# Epoch [1/100] - Val acc: 62.01%
#   New best model saved
# Epoch [2/100] - Val acc: 70.62%
#   New best model saved
# Epoch [3/100] - Val acc: 73.82%
#   New best model saved
# Epoch [4/100] - Val acc: 75.07%
#   New best model saved
# Epoch [5/100] - Val acc: 77.81%
#   New best model saved
# Epoch [6/100] - Val acc: 77.75%
# Epoch [7/100] - Val acc: 76.16%
# Epoch [8/100] - Val acc: 78.15%
#   New best model saved
# Epoch [9/100] - Val acc: 78.67%
#   New best model saved
# Epoch [10/100] - Val acc: 78.44%
# Epoch [11/100] - Val acc: 79.52%
#   New best model saved
# Epoch [12/100] - Val acc: 78.84%
# Epoch [13/100] - Val acc: 79.75%
#   New best model saved
# Epoch [14/100] - Val acc: 79.52%
# Epoch [15/100] - Val acc: 78.95%
# Epoch [16/100] - Val acc: 79.58%
# Epoch [17/100] - Val acc: 79.46%
# Epoch [18/100] - Val acc: 78.38%
# Epoch [19/100] - Val acc: 78.09%
# Epoch [20/100] - Val acc: 79.41%
# Epoch [21/100] - Val acc: 80.60%
#   New best model saved
# Epoch [22/100] - Val acc: 79.98%
# Epoch [23/100] - Val acc: 79.63%
# Epoch [24/100] - Val acc: 79.63%
# Epoch [25/100] - Val acc: 78.95%
# Epoch [26/100] - Val acc: 78.89%
# Epoch [27/100] - Val acc: 79.41%
# Epoch [28/100] - Val acc: 79.24%
# Epoch [29/100] - Val acc: 78.95%
# Epoch [30/100] - Val acc: 79.75%
# Epoch [31/100] - Val acc: 79.24%
# Epoch [32/100] - Val acc: 78.49%
# Epoch [33/100] - Val acc: 79.69%
# Epoch [34/100] - Val acc: 77.81%
# Epoch [35/100] - Val acc: 79.52%
# Epoch [36/100] - Val acc: 79.24%
# Early stopping triggered.
# c:\Users\solok\Desktop\Dcase baseline\dcase2026_task1_baseline\evaluate.py:97: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# [BaseClassifier | Fold final_test] Accuracy: 80.29%
# [BaseClassifier | Fold final_test] Top class accuracy: 89.37%
# [BaseClassifier | Fold final_test] Macro accuracy: 73.83%
# [BaseClassifier | Fold final_test] Macro top class accuracy: 84.82%
# [BaseClassifier | Fold final_test] Hierarchical accuracy: 79.32%
# [BaseClassifier | Fold final_test] Hierarchical precision: 79.29%
# [BaseClassifier | Fold final_test] Hierarchical recall: 77.95%
# [BaseClassifier | Fold final_test] Hierarchical F1: 78.40%
#   completed in 8.6 min
#
# [run] c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_2\both\fold_1
#   device=cuda:0 (NVIDIA GeForce RTX 3060, 8.6 GB)
#   samples: train=7010, val=1753, final_test=2192
#   batches: train=109, val=28, test=35
#   max_epochs=100, batch_size=64
# Epoch [1/100] - Val acc: 56.02%
#   New best model saved
# Epoch [2/100] - Val acc: 67.83%
#   New best model saved
# Epoch [3/100] - Val acc: 72.05%
#   New best model saved
# Epoch [4/100] - Val acc: 75.30%
#   New best model saved
# Epoch [5/100] - Val acc: 77.47%
#   New best model saved
# Epoch [6/100] - Val acc: 77.70%
#   New best model saved
# Epoch [7/100] - Val acc: 77.35%
# Epoch [8/100] - Val acc: 79.24%
#   New best model saved
# Epoch [9/100] - Val acc: 77.35%
# Epoch [10/100] - Val acc: 80.03%
#   New best model saved
# Epoch [11/100] - Val acc: 79.41%
# Epoch [12/100] - Val acc: 80.09%
#   New best model saved
# Epoch [13/100] - Val acc: 78.67%
# Epoch [14/100] - Val acc: 78.21%
# Epoch [15/100] - Val acc: 78.72%
# Epoch [16/100] - Val acc: 79.75%
# Epoch [17/100] - Val acc: 79.63%
# Epoch [18/100] - Val acc: 78.72%
# Epoch [19/100] - Val acc: 80.15%
#   New best model saved
# Epoch [20/100] - Val acc: 80.09%
# Epoch [21/100] - Val acc: 79.46%
# Epoch [22/100] - Val acc: 80.26%
#   New best model saved
# Epoch [23/100] - Val acc: 80.26%
# Epoch [24/100] - Val acc: 80.21%
# Epoch [25/100] - Val acc: 79.46%
# Epoch [26/100] - Val acc: 79.29%
# Epoch [27/100] - Val acc: 79.86%
# Epoch [28/100] - Val acc: 79.75%
# Epoch [29/100] - Val acc: 79.75%
# Epoch [30/100] - Val acc: 79.75%
# Epoch [31/100] - Val acc: 78.44%
# Epoch [32/100] - Val acc: 79.58%
# Epoch [33/100] - Val acc: 79.24%
# Epoch [34/100] - Val acc: 79.58%
# Epoch [35/100] - Val acc: 78.15%
# Epoch [36/100] - Val acc: 78.32%
# Epoch [37/100] - Val acc: 79.81%
# Early stopping triggered.
# c:\Users\solok\Desktop\Dcase baseline\dcase2026_task1_baseline\evaluate.py:97: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# [BaseClassifier | Fold final_test] Accuracy: 80.25%
# [BaseClassifier | Fold final_test] Top class accuracy: 89.01%
# [BaseClassifier | Fold final_test] Macro accuracy: 74.70%
# [BaseClassifier | Fold final_test] Macro top class accuracy: 84.94%
# [BaseClassifier | Fold final_test] Hierarchical accuracy: 79.82%
# [BaseClassifier | Fold final_test] Hierarchical precision: 79.65%
# [BaseClassifier | Fold final_test] Hierarchical recall: 78.54%
# [BaseClassifier | Fold final_test] Hierarchical F1: 78.86%
#   completed in 9.0 min
#
# [run] c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_2\both\fold_2
#   device=cuda:0 (NVIDIA GeForce RTX 3060, 8.6 GB)
#   samples: train=7010, val=1753, final_test=2192
#   batches: train=109, val=28, test=35
#   max_epochs=100, batch_size=64
# Epoch [1/100] - Val acc: 58.64%
#   New best model saved
# Epoch [2/100] - Val acc: 66.91%
#   New best model saved
# Epoch [3/100] - Val acc: 73.47%
#   New best model saved
# Epoch [4/100] - Val acc: 74.90%
#   New best model saved
# Epoch [5/100] - Val acc: 77.01%
#   New best model saved
# Epoch [6/100] - Val acc: 77.24%
#   New best model saved
# Epoch [7/100] - Val acc: 77.47%
#   New best model saved
# Epoch [8/100] - Val acc: 78.44%
#   New best model saved
# Epoch [9/100] - Val acc: 77.47%
# Epoch [10/100] - Val acc: 79.52%
#   New best model saved
# Epoch [11/100] - Val acc: 77.81%
# Epoch [12/100] - Val acc: 78.27%
# Epoch [13/100] - Val acc: 79.01%
# Epoch [14/100] - Val acc: 78.67%
# Epoch [15/100] - Val acc: 78.72%
# Epoch [16/100] - Val acc: 78.89%
# Epoch [17/100] - Val acc: 79.24%
# Epoch [18/100] - Val acc: 77.98%
# Epoch [19/100] - Val acc: 78.89%
# Epoch [20/100] - Val acc: 78.15%
# Epoch [21/100] - Val acc: 78.38%
# Epoch [22/100] - Val acc: 79.41%
# Epoch [23/100] - Val acc: 79.06%
# Epoch [24/100] - Val acc: 79.81%
#   New best model saved
# Epoch [25/100] - Val acc: 79.12%
# Epoch [26/100] - Val acc: 77.92%
# Epoch [27/100] - Val acc: 79.46%
# Epoch [28/100] - Val acc: 78.49%
# Epoch [29/100] - Val acc: 78.38%
# Epoch [30/100] - Val acc: 78.21%
# Epoch [31/100] - Val acc: 78.27%
# Epoch [32/100] - Val acc: 77.52%
# Epoch [33/100] - Val acc: 78.09%
# Epoch [34/100] - Val acc: 78.49%
# Epoch [35/100] - Val acc: 77.98%
# Epoch [36/100] - Val acc: 78.49%
# Epoch [37/100] - Val acc: 78.49%
# Epoch [38/100] - Val acc: 77.75%
# Epoch [39/100] - Val acc: 77.75%
# Early stopping triggered.
# c:\Users\solok\Desktop\Dcase baseline\dcase2026_task1_baseline\evaluate.py:97: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# [BaseClassifier | Fold final_test] Accuracy: 80.84%
# [BaseClassifier | Fold final_test] Top class accuracy: 89.14%
# [BaseClassifier | Fold final_test] Macro accuracy: 75.35%
# [BaseClassifier | Fold final_test] Macro top class accuracy: 84.88%
# [BaseClassifier | Fold final_test] Hierarchical accuracy: 80.11%
# [BaseClassifier | Fold final_test] Hierarchical precision: 79.96%
# [BaseClassifier | Fold final_test] Hierarchical recall: 78.92%
# [BaseClassifier | Fold final_test] Hierarchical F1: 79.31%
#   completed in 9.6 min
#
# [run] c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_2\both\fold_3
#   device=cuda:0 (NVIDIA GeForce RTX 3060, 8.6 GB)
#   samples: train=7011, val=1752, final_test=2192
#   batches: train=109, val=28, test=35
#   max_epochs=100, batch_size=64
# Epoch [1/100] - Val acc: 51.77%
#   New best model saved
# Epoch [2/100] - Val acc: 68.21%
#   New best model saved
# Epoch [3/100] - Val acc: 73.69%
#   New best model saved
# Epoch [4/100] - Val acc: 74.09%
#   New best model saved
# Epoch [5/100] - Val acc: 74.89%
#   New best model saved
# Epoch [6/100] - Val acc: 76.54%
#   New best model saved
# Epoch [7/100] - Val acc: 77.51%
#   New best model saved
# Epoch [8/100] - Val acc: 77.85%
#   New best model saved
# Epoch [9/100] - Val acc: 77.80%
# Epoch [10/100] - Val acc: 78.77%
#   New best model saved
# Epoch [11/100] - Val acc: 78.82%
#   New best model saved
# Epoch [12/100] - Val acc: 78.48%
# Epoch [13/100] - Val acc: 78.77%
# Epoch [14/100] - Val acc: 77.85%
# Epoch [15/100] - Val acc: 78.77%
# Epoch [16/100] - Val acc: 79.05%
#   New best model saved
# Epoch [17/100] - Val acc: 78.94%
# Epoch [18/100] - Val acc: 79.28%
#   New best model saved
# Epoch [19/100] - Val acc: 79.17%
# Epoch [20/100] - Val acc: 78.71%
# Epoch [21/100] - Val acc: 79.97%
#   New best model saved
# Epoch [22/100] - Val acc: 79.57%
# Epoch [23/100] - Val acc: 79.00%
# Epoch [24/100] - Val acc: 79.39%
# Epoch [25/100] - Val acc: 78.60%
# Epoch [26/100] - Val acc: 79.79%
# Epoch [27/100] - Val acc: 79.17%
# Epoch [28/100] - Val acc: 78.94%
# Epoch [29/100] - Val acc: 78.88%
# Epoch [30/100] - Val acc: 79.68%
# Epoch [31/100] - Val acc: 78.25%
# Epoch [32/100] - Val acc: 78.60%
# Epoch [33/100] - Val acc: 78.37%
# Epoch [34/100] - Val acc: 78.20%
# Epoch [35/100] - Val acc: 79.39%
# Epoch [36/100] - Val acc: 78.88%
# Early stopping triggered.
# c:\Users\solok\Desktop\Dcase baseline\dcase2026_task1_baseline\evaluate.py:97: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# [BaseClassifier | Fold final_test] Accuracy: 81.25%
# [BaseClassifier | Fold final_test] Top class accuracy: 89.51%
# [BaseClassifier | Fold final_test] Macro accuracy: 75.71%
# [BaseClassifier | Fold final_test] Macro top class accuracy: 85.59%
# [BaseClassifier | Fold final_test] Hierarchical accuracy: 80.65%
# [BaseClassifier | Fold final_test] Hierarchical precision: 80.82%
# [BaseClassifier | Fold final_test] Hierarchical recall: 79.42%
# [BaseClassifier | Fold final_test] Hierarchical F1: 79.78%
#   completed in 8.8 min
#
# [run] c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_2\both\fold_4
#   device=cuda:0 (NVIDIA GeForce RTX 3060, 8.6 GB)
#   samples: train=7011, val=1752, final_test=2192
#   batches: train=109, val=28, test=35
#   max_epochs=100, batch_size=64
# Epoch [1/100] - Val acc: 58.79%
#   New best model saved
# Epoch [2/100] - Val acc: 69.98%
#   New best model saved
# Epoch [3/100] - Val acc: 71.40%
#   New best model saved
# Epoch [4/100] - Val acc: 75.86%
#   New best model saved
# Epoch [5/100] - Val acc: 75.86%
# Epoch [6/100] - Val acc: 78.37%
#   New best model saved
# Epoch [7/100] - Val acc: 77.28%
# Epoch [8/100] - Val acc: 77.85%
# Epoch [9/100] - Val acc: 79.62%
#   New best model saved
# Epoch [10/100] - Val acc: 78.37%
# Epoch [11/100] - Val acc: 79.00%
# Epoch [12/100] - Val acc: 78.82%
# Epoch [13/100] - Val acc: 77.57%
# Epoch [14/100] - Val acc: 79.28%
# Epoch [15/100] - Val acc: 79.22%
# Epoch [16/100] - Val acc: 78.94%
# Epoch [17/100] - Val acc: 79.11%
# Epoch [18/100] - Val acc: 78.31%
# Epoch [19/100] - Val acc: 79.05%
# Epoch [20/100] - Val acc: 78.31%
# Epoch [21/100] - Val acc: 79.00%
# Epoch [22/100] - Val acc: 78.42%
# Epoch [23/100] - Val acc: 79.39%
# Epoch [24/100] - Val acc: 79.34%
# Early stopping triggered.
# c:\Users\solok\Desktop\Dcase baseline\dcase2026_task1_baseline\evaluate.py:97: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# [BaseClassifier | Fold final_test] Accuracy: 79.20%
# [BaseClassifier | Fold final_test] Top class accuracy: 88.09%
# [BaseClassifier | Fold final_test] Macro accuracy: 71.30%
# [BaseClassifier | Fold final_test] Macro top class accuracy: 82.32%
# [BaseClassifier | Fold final_test] Hierarchical accuracy: 76.81%
# [BaseClassifier | Fold final_test] Hierarchical precision: 79.44%
# [BaseClassifier | Fold final_test] Hierarchical recall: 75.44%
# [BaseClassifier | Fold final_test] Hierarchical F1: 76.33%
#   completed in 5.9 min
#
# [run] c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_3\both\fold_0
#   device=cuda:0 (NVIDIA GeForce RTX 3060, 8.6 GB)
#   samples: train=6524, val=1631, final_test=2192
#   batches: train=101, val=26, test=35
#   max_epochs=100, batch_size=64
# Epoch [1/100] - Val acc: 51.69%
#   New best model saved
# Epoch [2/100] - Val acc: 68.85%
#   New best model saved
# Epoch [3/100] - Val acc: 73.15%
#   New best model saved
# Epoch [4/100] - Val acc: 75.48%
#   New best model saved
# Epoch [5/100] - Val acc: 77.68%
#   New best model saved
# Epoch [6/100] - Val acc: 77.74%
#   New best model saved
# Epoch [7/100] - Val acc: 77.99%
#   New best model saved
# Epoch [8/100] - Val acc: 78.17%
#   New best model saved
# Epoch [9/100] - Val acc: 79.34%
#   New best model saved
# Epoch [10/100] - Val acc: 79.40%
#   New best model saved
# Epoch [11/100] - Val acc: 79.83%
#   New best model saved
# Epoch [12/100] - Val acc: 79.58%
# Epoch [13/100] - Val acc: 78.42%
# Epoch [14/100] - Val acc: 79.95%
#   New best model saved
# Epoch [15/100] - Val acc: 80.69%
#   New best model saved
# Epoch [16/100] - Val acc: 78.79%
# Epoch [17/100] - Val acc: 79.71%
# Epoch [18/100] - Val acc: 79.77%
# Epoch [19/100] - Val acc: 78.91%
# Epoch [20/100] - Val acc: 80.07%
# Epoch [21/100] - Val acc: 80.75%
#   New best model saved
# Epoch [22/100] - Val acc: 80.44%
# Epoch [23/100] - Val acc: 80.44%
# Epoch [24/100] - Val acc: 80.69%
# Epoch [25/100] - Val acc: 80.26%
# Epoch [26/100] - Val acc: 80.01%
# Epoch [27/100] - Val acc: 80.07%
# Epoch [28/100] - Val acc: 79.83%
# Epoch [29/100] - Val acc: 80.01%
# Epoch [30/100] - Val acc: 80.75%
# Epoch [31/100] - Val acc: 80.75%
# Epoch [32/100] - Val acc: 79.46%
# Epoch [33/100] - Val acc: 79.28%
# Epoch [34/100] - Val acc: 80.38%
# Epoch [35/100] - Val acc: 79.71%
# Epoch [36/100] - Val acc: 79.46%
# Early stopping triggered.
# c:\Users\solok\Desktop\Dcase baseline\dcase2026_task1_baseline\evaluate.py:97: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# [BaseClassifier | Fold final_test] Accuracy: 80.29%
# [BaseClassifier | Fold final_test] Top class accuracy: 89.83%
# [BaseClassifier | Fold final_test] Macro accuracy: 74.22%
# [BaseClassifier | Fold final_test] Macro top class accuracy: 85.37%
# [BaseClassifier | Fold final_test] Hierarchical accuracy: 79.79%
# [BaseClassifier | Fold final_test] Hierarchical precision: 79.25%
# [BaseClassifier | Fold final_test] Hierarchical recall: 78.40%
# [BaseClassifier | Fold final_test] Hierarchical F1: 78.66%
#   completed in 4.7 min
#
# [run] c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_3\both\fold_1
#   device=cuda:0 (NVIDIA GeForce RTX 3060, 8.6 GB)
#   samples: train=6524, val=1631, final_test=2192
#   batches: train=101, val=26, test=35
#   max_epochs=100, batch_size=64
# Epoch [1/100] - Val acc: 59.47%
#   New best model saved
# Epoch [2/100] - Val acc: 69.90%
#   New best model saved
# Epoch [3/100] - Val acc: 74.74%
#   New best model saved
# Epoch [4/100] - Val acc: 76.70%
#   New best model saved
# Epoch [5/100] - Val acc: 76.70%
# Epoch [6/100] - Val acc: 79.46%
#   New best model saved
# Epoch [7/100] - Val acc: 78.05%
# Epoch [8/100] - Val acc: 78.42%
# Epoch [9/100] - Val acc: 78.17%
# Epoch [10/100] - Val acc: 78.97%
# Epoch [11/100] - Val acc: 78.42%
# Epoch [12/100] - Val acc: 79.52%
#   New best model saved
# Epoch [13/100] - Val acc: 79.89%
#   New best model saved
# Epoch [14/100] - Val acc: 79.46%
# Epoch [15/100] - Val acc: 79.83%
# Epoch [16/100] - Val acc: 79.64%
# Epoch [17/100] - Val acc: 79.58%
# Epoch [18/100] - Val acc: 79.58%
# Epoch [19/100] - Val acc: 80.20%
#   New best model saved
# Epoch [20/100] - Val acc: 80.01%
# Epoch [21/100] - Val acc: 80.38%
#   New best model saved
# Epoch [22/100] - Val acc: 79.83%
# Epoch [23/100] - Val acc: 80.07%
# Epoch [24/100] - Val acc: 79.58%
# Epoch [25/100] - Val acc: 80.13%
# Epoch [26/100] - Val acc: 79.03%
# Epoch [27/100] - Val acc: 79.46%
# Epoch [28/100] - Val acc: 80.32%
# Epoch [29/100] - Val acc: 79.15%
# Epoch [30/100] - Val acc: 78.60%
# Epoch [31/100] - Val acc: 79.46%
# Epoch [32/100] - Val acc: 79.58%
# Epoch [33/100] - Val acc: 79.71%
# Epoch [34/100] - Val acc: 79.83%
# Epoch [35/100] - Val acc: 79.40%
# Epoch [36/100] - Val acc: 79.71%
# Early stopping triggered.
# c:\Users\solok\Desktop\Dcase baseline\dcase2026_task1_baseline\evaluate.py:97: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# [BaseClassifier | Fold final_test] Accuracy: 80.70%
# [BaseClassifier | Fold final_test] Top class accuracy: 89.23%
# [BaseClassifier | Fold final_test] Macro accuracy: 74.85%
# [BaseClassifier | Fold final_test] Macro top class accuracy: 85.15%
# [BaseClassifier | Fold final_test] Hierarchical accuracy: 80.00%
# [BaseClassifier | Fold final_test] Hierarchical precision: 79.23%
# [BaseClassifier | Fold final_test] Hierarchical recall: 78.71%
# [BaseClassifier | Fold final_test] Hierarchical F1: 78.58%
#   completed in 4.1 min
#
# [run] c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_3\both\fold_2
#   device=cuda:0 (NVIDIA GeForce RTX 3060, 8.6 GB)
#   samples: train=6524, val=1631, final_test=2192
#   batches: train=101, val=26, test=35
#   max_epochs=100, batch_size=64
# Epoch [1/100] - Val acc: 57.08%
#   New best model saved
# Epoch [2/100] - Val acc: 69.71%
#   New best model saved
# Epoch [3/100] - Val acc: 73.02%
#   New best model saved
# Epoch [4/100] - Val acc: 75.29%
#   New best model saved
# Epoch [5/100] - Val acc: 77.07%
#   New best model saved
# Epoch [6/100] - Val acc: 79.46%
#   New best model saved
# Epoch [7/100] - Val acc: 78.97%
# Epoch [8/100] - Val acc: 79.28%
# Epoch [9/100] - Val acc: 77.81%
# Epoch [10/100] - Val acc: 79.58%
#   New best model saved
# Epoch [11/100] - Val acc: 80.63%
#   New best model saved
# Epoch [12/100] - Val acc: 80.87%
#   New best model saved
# Epoch [13/100] - Val acc: 80.01%
# Epoch [14/100] - Val acc: 80.69%
# Epoch [15/100] - Val acc: 79.83%
# Epoch [16/100] - Val acc: 80.50%
# Epoch [17/100] - Val acc: 79.89%
# Epoch [18/100] - Val acc: 80.01%
# Epoch [19/100] - Val acc: 80.69%
# Epoch [20/100] - Val acc: 80.75%
# Epoch [21/100] - Val acc: 81.61%
#   New best model saved
# Epoch [22/100] - Val acc: 81.61%
# Epoch [23/100] - Val acc: 81.12%
# Epoch [24/100] - Val acc: 80.32%
# Epoch [25/100] - Val acc: 80.93%
# Epoch [26/100] - Val acc: 80.20%
# Epoch [27/100] - Val acc: 81.42%
# Epoch [28/100] - Val acc: 81.12%
# Epoch [29/100] - Val acc: 80.13%
# Epoch [30/100] - Val acc: 81.48%
# Epoch [31/100] - Val acc: 80.69%
# Epoch [32/100] - Val acc: 80.75%
# Epoch [33/100] - Val acc: 79.71%
# Epoch [34/100] - Val acc: 81.12%
# Epoch [35/100] - Val acc: 80.56%
# Epoch [36/100] - Val acc: 80.93%
# Early stopping triggered.
# c:\Users\solok\Desktop\Dcase baseline\dcase2026_task1_baseline\evaluate.py:97: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# [BaseClassifier | Fold final_test] Accuracy: 79.97%
# [BaseClassifier | Fold final_test] Top class accuracy: 89.23%
# [BaseClassifier | Fold final_test] Macro accuracy: 74.62%
# [BaseClassifier | Fold final_test] Macro top class accuracy: 85.16%
# [BaseClassifier | Fold final_test] Hierarchical accuracy: 79.89%
# [BaseClassifier | Fold final_test] Hierarchical precision: 79.90%
# [BaseClassifier | Fold final_test] Hierarchical recall: 78.57%
# [BaseClassifier | Fold final_test] Hierarchical F1: 78.94%
#   completed in 4.2 min
#
# [run] c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_3\both\fold_3
#   device=cuda:0 (NVIDIA GeForce RTX 3060, 8.6 GB)
#   samples: train=6524, val=1631, final_test=2192
#   batches: train=101, val=26, test=35
#   max_epochs=100, batch_size=64
# Epoch [1/100] - Val acc: 58.00%
#   New best model saved
# Epoch [2/100] - Val acc: 70.20%
#   New best model saved
# Epoch [3/100] - Val acc: 74.56%
#   New best model saved
# Epoch [4/100] - Val acc: 76.33%
#   New best model saved
# Epoch [5/100] - Val acc: 77.68%
#   New best model saved
# Epoch [6/100] - Val acc: 77.99%
#   New best model saved
# Epoch [7/100] - Val acc: 78.79%
#   New best model saved
# Epoch [8/100] - Val acc: 79.22%
#   New best model saved
# Epoch [9/100] - Val acc: 78.85%
# Epoch [10/100] - Val acc: 80.44%
#   New best model saved
# Epoch [11/100] - Val acc: 79.22%
# Epoch [12/100] - Val acc: 80.50%
#   New best model saved
# Epoch [13/100] - Val acc: 80.44%
# Epoch [14/100] - Val acc: 80.63%
#   New best model saved
# Epoch [15/100] - Val acc: 80.13%
# Epoch [16/100] - Val acc: 80.75%
#   New best model saved
# Epoch [17/100] - Val acc: 80.32%
# Epoch [18/100] - Val acc: 80.26%
# Epoch [19/100] - Val acc: 79.46%
# Epoch [20/100] - Val acc: 80.32%
# Epoch [21/100] - Val acc: 81.67%
#   New best model saved
# Epoch [22/100] - Val acc: 80.69%
# Epoch [23/100] - Val acc: 80.69%
# Epoch [24/100] - Val acc: 80.44%
# Epoch [25/100] - Val acc: 80.93%
# Epoch [26/100] - Val acc: 79.77%
# Epoch [27/100] - Val acc: 80.56%
# Epoch [28/100] - Val acc: 80.69%
# Epoch [29/100] - Val acc: 80.07%
# Epoch [30/100] - Val acc: 80.38%
# Epoch [31/100] - Val acc: 80.07%
# Epoch [32/100] - Val acc: 79.77%
# Epoch [33/100] - Val acc: 79.52%
# Epoch [34/100] - Val acc: 79.83%
# Epoch [35/100] - Val acc: 79.58%
# Epoch [36/100] - Val acc: 80.38%
# Early stopping triggered.
# c:\Users\solok\Desktop\Dcase baseline\dcase2026_task1_baseline\evaluate.py:97: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# [BaseClassifier | Fold final_test] Accuracy: 80.02%
# [BaseClassifier | Fold final_test] Top class accuracy: 89.37%
# [BaseClassifier | Fold final_test] Macro accuracy: 73.09%
# [BaseClassifier | Fold final_test] Macro top class accuracy: 84.72%
# [BaseClassifier | Fold final_test] Hierarchical accuracy: 78.91%
# [BaseClassifier | Fold final_test] Hierarchical precision: 79.80%
# [BaseClassifier | Fold final_test] Hierarchical recall: 77.45%
# [BaseClassifier | Fold final_test] Hierarchical F1: 78.00%
#   completed in 6.5 min
#
# [run] c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_3\both\fold_4
#   device=cuda:0 (NVIDIA GeForce RTX 3060, 8.6 GB)
#   samples: train=6524, val=1631, final_test=2192
#   batches: train=101, val=26, test=35
#   max_epochs=100, batch_size=64
# Epoch [1/100] - Val acc: 59.96%
#   New best model saved
# Epoch [2/100] - Val acc: 69.47%
#   New best model saved
# Epoch [3/100] - Val acc: 73.88%
#   New best model saved
# Epoch [4/100] - Val acc: 75.41%
#   New best model saved
# Epoch [5/100] - Val acc: 74.80%
# Epoch [6/100] - Val acc: 77.31%
#   New best model saved
# Epoch [7/100] - Val acc: 79.58%
#   New best model saved
# Epoch [8/100] - Val acc: 78.23%
# Epoch [9/100] - Val acc: 79.22%
# Epoch [10/100] - Val acc: 78.97%
# Epoch [11/100] - Val acc: 78.54%
# Epoch [12/100] - Val acc: 79.77%
#   New best model saved
# Epoch [13/100] - Val acc: 80.44%
#   New best model saved
# Epoch [14/100] - Val acc: 79.58%
# Epoch [15/100] - Val acc: 80.07%
# Epoch [16/100] - Val acc: 80.20%
# Epoch [17/100] - Val acc: 81.79%
#   New best model saved
# Epoch [18/100] - Val acc: 80.01%
# Epoch [19/100] - Val acc: 78.66%
# Epoch [20/100] - Val acc: 78.60%
# Epoch [21/100] - Val acc: 80.75%
# Epoch [22/100] - Val acc: 81.48%
# Epoch [23/100] - Val acc: 80.32%
# Epoch [24/100] - Val acc: 80.01%
# Epoch [25/100] - Val acc: 80.75%
# Epoch [26/100] - Val acc: 81.42%
# Epoch [27/100] - Val acc: 81.05%
# Epoch [28/100] - Val acc: 80.44%
# Epoch [29/100] - Val acc: 81.18%
# Epoch [30/100] - Val acc: 80.20%
# Epoch [31/100] - Val acc: 81.05%
# Epoch [32/100] - Val acc: 80.75%
# Early stopping triggered.
# c:\Users\solok\Desktop\Dcase baseline\dcase2026_task1_baseline\evaluate.py:97: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# [BaseClassifier | Fold final_test] Accuracy: 79.79%
# [BaseClassifier | Fold final_test] Top class accuracy: 89.46%
# [BaseClassifier | Fold final_test] Macro accuracy: 73.26%
# [BaseClassifier | Fold final_test] Macro top class accuracy: 84.88%
# [BaseClassifier | Fold final_test] Hierarchical accuracy: 79.07%
# [BaseClassifier | Fold final_test] Hierarchical precision: 79.00%
# [BaseClassifier | Fold final_test] Hierarchical recall: 77.62%
# [BaseClassifier | Fold final_test] Hierarchical F1: 77.96%
#   completed in 3.9 min
#
# [run] c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_4\both\fold_0
#   device=cuda:0 (NVIDIA GeForce RTX 3060, 8.6 GB)
#   samples: train=1031, val=258, final_test=2192
#   batches: train=16, val=5, test=35
#   max_epochs=100, batch_size=64
# c:\Users\solok\Desktop\Dcase baseline\.venv\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Epoch [1/100] - Val acc: 27.91%
#   New best model saved
# Epoch [2/100] - Val acc: 51.16%
#   New best model saved
# Epoch [3/100] - Val acc: 74.81%
#   New best model saved
# Epoch [4/100] - Val acc: 85.66%
#   New best model saved
# Epoch [5/100] - Val acc: 86.05%
#   New best model saved
# Epoch [6/100] - Val acc: 86.82%
#   New best model saved
# Epoch [7/100] - Val acc: 88.37%
#   New best model saved
# Epoch [8/100] - Val acc: 87.21%
# Epoch [9/100] - Val acc: 88.76%
#   New best model saved
# Epoch [10/100] - Val acc: 89.92%
#   New best model saved
# Epoch [11/100] - Val acc: 90.70%
#   New best model saved
# Epoch [12/100] - Val acc: 88.76%
# Epoch [13/100] - Val acc: 89.15%
# Epoch [14/100] - Val acc: 89.92%
# Epoch [15/100] - Val acc: 89.53%
# Epoch [16/100] - Val acc: 89.15%
# Epoch [17/100] - Val acc: 89.53%
# Epoch [18/100] - Val acc: 88.37%
# Epoch [19/100] - Val acc: 89.92%
# Epoch [20/100] - Val acc: 91.47%
#   New best model saved
# Epoch [21/100] - Val acc: 90.70%
# Epoch [22/100] - Val acc: 91.09%
# Epoch [23/100] - Val acc: 90.31%
# Epoch [24/100] - Val acc: 90.70%
# Epoch [25/100] - Val acc: 90.70%
# Epoch [26/100] - Val acc: 90.31%
# Epoch [27/100] - Val acc: 91.86%
#   New best model saved
# Epoch [28/100] - Val acc: 90.70%
# Epoch [29/100] - Val acc: 89.92%
# Epoch [30/100] - Val acc: 90.31%
# Epoch [31/100] - Val acc: 90.70%
# Epoch [32/100] - Val acc: 91.47%
# Epoch [33/100] - Val acc: 91.86%
# Epoch [34/100] - Val acc: 91.47%
# Epoch [35/100] - Val acc: 91.47%
# Epoch [36/100] - Val acc: 91.09%
# Epoch [37/100] - Val acc: 91.86%
# Epoch [38/100] - Val acc: 90.70%
# Epoch [39/100] - Val acc: 90.31%
# Epoch [40/100] - Val acc: 89.53%
# Epoch [41/100] - Val acc: 89.53%
# Epoch [42/100] - Val acc: 90.31%
# Early stopping triggered.
# c:\Users\solok\Desktop\Dcase baseline\dcase2026_task1_baseline\evaluate.py:97: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# [BaseClassifier | Fold final_test] Accuracy: 58.39%
# [BaseClassifier | Fold final_test] Top class accuracy: 76.41%
# [BaseClassifier | Fold final_test] Macro accuracy: 44.30%
# [BaseClassifier | Fold final_test] Macro top class accuracy: 68.72%
# [BaseClassifier | Fold final_test] Hierarchical accuracy: 56.51%
# [BaseClassifier | Fold final_test] Hierarchical precision: 59.27%
# [BaseClassifier | Fold final_test] Hierarchical recall: 68.30%
# [BaseClassifier | Fold final_test] Hierarchical F1: 61.88%
#   completed in 1.0 min
#
# [run] c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_4\both\fold_1
#   device=cuda:0 (NVIDIA GeForce RTX 3060, 8.6 GB)
#   samples: train=1031, val=258, final_test=2192
#   batches: train=16, val=5, test=35
#   max_epochs=100, batch_size=64
# Epoch [1/100] - Val acc: 26.36%
#   New best model saved
# Epoch [2/100] - Val acc: 63.57%
#   New best model saved
# Epoch [3/100] - Val acc: 81.01%
#   New best model saved
# Epoch [4/100] - Val acc: 86.43%
#   New best model saved
# Epoch [5/100] - Val acc: 87.60%
#   New best model saved
# Epoch [6/100] - Val acc: 90.70%
#   New best model saved
# Epoch [7/100] - Val acc: 92.25%
#   New best model saved
# Epoch [8/100] - Val acc: 90.31%
# Epoch [9/100] - Val acc: 91.86%
# Epoch [10/100] - Val acc: 92.25%
# Epoch [11/100] - Val acc: 91.86%
# Epoch [12/100] - Val acc: 90.70%
# Epoch [13/100] - Val acc: 91.86%
# Epoch [14/100] - Val acc: 91.47%
# Epoch [15/100] - Val acc: 92.64%
#   New best model saved
# Epoch [16/100] - Val acc: 90.70%
# Epoch [17/100] - Val acc: 91.47%
# Epoch [18/100] - Val acc: 93.02%
#   New best model saved
# Epoch [19/100] - Val acc: 89.53%
# Epoch [20/100] - Val acc: 91.47%
# Epoch [21/100] - Val acc: 92.64%
# Epoch [22/100] - Val acc: 93.02%
# Epoch [23/100] - Val acc: 92.25%
# Epoch [24/100] - Val acc: 92.64%
# Epoch [25/100] - Val acc: 93.41%
#   New best model saved
# Epoch [26/100] - Val acc: 93.80%
#   New best model saved
# Epoch [27/100] - Val acc: 93.41%
# Epoch [28/100] - Val acc: 94.19%
#   New best model saved
# Epoch [29/100] - Val acc: 94.19%
# Epoch [30/100] - Val acc: 93.41%
# Epoch [31/100] - Val acc: 93.80%
# Epoch [32/100] - Val acc: 94.19%
# Epoch [33/100] - Val acc: 94.19%
# Epoch [34/100] - Val acc: 93.02%
# Epoch [35/100] - Val acc: 93.41%
# Epoch [36/100] - Val acc: 92.64%
# Epoch [37/100] - Val acc: 93.41%
# Epoch [38/100] - Val acc: 93.80%
# Epoch [39/100] - Val acc: 93.02%
# Epoch [40/100] - Val acc: 92.64%
# Epoch [41/100] - Val acc: 91.86%
# Epoch [42/100] - Val acc: 93.02%
# Epoch [43/100] - Val acc: 93.02%
# Early stopping triggered.
# c:\Users\solok\Desktop\Dcase baseline\dcase2026_task1_baseline\evaluate.py:97: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# [BaseClassifier | Fold final_test] Accuracy: 57.44%
# [BaseClassifier | Fold final_test] Top class accuracy: 74.32%
# [BaseClassifier | Fold final_test] Macro accuracy: 42.59%
# [BaseClassifier | Fold final_test] Macro top class accuracy: 64.68%
# [BaseClassifier | Fold final_test] Hierarchical accuracy: 53.64%
# [BaseClassifier | Fold final_test] Hierarchical precision: 57.71%
# [BaseClassifier | Fold final_test] Hierarchical recall: 68.39%
# [BaseClassifier | Fold final_test] Hierarchical F1: 62.13%
#   completed in 0.8 min
#
# [run] c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_4\both\fold_2
#   device=cuda:0 (NVIDIA GeForce RTX 3060, 8.6 GB)
#   samples: train=1031, val=258, final_test=2192
#   batches: train=16, val=5, test=35
#   max_epochs=100, batch_size=64
# Epoch [1/100] - Val acc: 8.14%
#   New best model saved
# Epoch [2/100] - Val acc: 58.91%
#   New best model saved
# Epoch [3/100] - Val acc: 76.36%
#   New best model saved
# Epoch [4/100] - Val acc: 86.82%
#   New best model saved
# Epoch [5/100] - Val acc: 86.05%
# Epoch [6/100] - Val acc: 88.76%
#   New best model saved
# Epoch [7/100] - Val acc: 89.53%
#   New best model saved
# Epoch [8/100] - Val acc: 89.92%
#   New best model saved
# Epoch [9/100] - Val acc: 91.86%
#   New best model saved
# Epoch [10/100] - Val acc: 92.64%
#   New best model saved
# Epoch [11/100] - Val acc: 91.09%
# Epoch [12/100] - Val acc: 91.09%
# Epoch [13/100] - Val acc: 93.02%
#   New best model saved
# Epoch [14/100] - Val acc: 91.47%
# Epoch [15/100] - Val acc: 93.02%
# Epoch [16/100] - Val acc: 94.19%
#   New best model saved
# Epoch [17/100] - Val acc: 93.02%
# Epoch [18/100] - Val acc: 93.02%
# Epoch [19/100] - Val acc: 91.86%
# Epoch [20/100] - Val acc: 94.19%
# Epoch [21/100] - Val acc: 93.41%
# Epoch [22/100] - Val acc: 93.41%
# Epoch [23/100] - Val acc: 93.80%
# Epoch [24/100] - Val acc: 92.64%
# Epoch [25/100] - Val acc: 93.80%
# Epoch [26/100] - Val acc: 91.47%
# Epoch [27/100] - Val acc: 93.80%
# Epoch [28/100] - Val acc: 93.80%
# Epoch [29/100] - Val acc: 92.64%
# Epoch [30/100] - Val acc: 93.80%
# Epoch [31/100] - Val acc: 93.02%
# Early stopping triggered.
# c:\Users\solok\Desktop\Dcase baseline\dcase2026_task1_baseline\evaluate.py:97: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# [BaseClassifier | Fold final_test] Accuracy: 54.88%
# [BaseClassifier | Fold final_test] Top class accuracy: 74.59%
# [BaseClassifier | Fold final_test] Macro accuracy: 39.71%
# [BaseClassifier | Fold final_test] Macro top class accuracy: 67.82%
# [BaseClassifier | Fold final_test] Hierarchical accuracy: 53.76%
# [BaseClassifier | Fold final_test] Hierarchical precision: 60.39%
# [BaseClassifier | Fold final_test] Hierarchical recall: 72.05%
# [BaseClassifier | Fold final_test] Hierarchical F1: 64.82%
#   completed in 0.8 min
#
# [run] c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_4\both\fold_3
#   device=cuda:0 (NVIDIA GeForce RTX 3060, 8.6 GB)
#   samples: train=1031, val=258, final_test=2192
#   batches: train=16, val=5, test=35
#   max_epochs=100, batch_size=64
# Epoch [1/100] - Val acc: 17.83%
#   New best model saved
# Epoch [2/100] - Val acc: 43.80%
#   New best model saved
# Epoch [3/100] - Val acc: 75.97%
#   New best model saved
# Epoch [4/100] - Val acc: 84.50%
#   New best model saved
# Epoch [5/100] - Val acc: 85.66%
#   New best model saved
# Epoch [6/100] - Val acc: 87.98%
#   New best model saved
# Epoch [7/100] - Val acc: 89.53%
#   New best model saved
# Epoch [8/100] - Val acc: 90.70%
#   New best model saved
# Epoch [9/100] - Val acc: 89.92%
# Epoch [10/100] - Val acc: 91.09%
#   New best model saved
# Epoch [11/100] - Val acc: 89.15%
# Epoch [12/100] - Val acc: 91.47%
#   New best model saved
# Epoch [13/100] - Val acc: 91.86%
#   New best model saved
# Epoch [14/100] - Val acc: 90.31%
# Epoch [15/100] - Val acc: 91.86%
# Epoch [16/100] - Val acc: 91.86%
# Epoch [17/100] - Val acc: 93.80%
#   New best model saved
# Epoch [18/100] - Val acc: 93.41%
# Epoch [19/100] - Val acc: 92.25%
# Epoch [20/100] - Val acc: 93.41%
# Epoch [21/100] - Val acc: 92.64%
# Epoch [22/100] - Val acc: 92.25%
# Epoch [23/100] - Val acc: 90.70%
# Epoch [24/100] - Val acc: 90.70%
# Epoch [25/100] - Val acc: 92.25%
# Epoch [26/100] - Val acc: 91.47%
# Epoch [27/100] - Val acc: 92.25%
# Epoch [28/100] - Val acc: 92.64%
# Epoch [29/100] - Val acc: 91.86%
# Epoch [30/100] - Val acc: 90.70%
# Epoch [31/100] - Val acc: 91.86%
# Epoch [32/100] - Val acc: 92.25%
# Early stopping triggered.
# c:\Users\solok\Desktop\Dcase baseline\dcase2026_task1_baseline\evaluate.py:97: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# [BaseClassifier | Fold final_test] Accuracy: 56.89%
# [BaseClassifier | Fold final_test] Top class accuracy: 74.86%
# [BaseClassifier | Fold final_test] Macro accuracy: 43.46%
# [BaseClassifier | Fold final_test] Macro top class accuracy: 67.09%
# [BaseClassifier | Fold final_test] Hierarchical accuracy: 55.27%
# [BaseClassifier | Fold final_test] Hierarchical precision: 62.46%
# [BaseClassifier | Fold final_test] Hierarchical recall: 72.70%
# [BaseClassifier | Fold final_test] Hierarchical F1: 66.08%
#   completed in 0.6 min
#
# [run] c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_4\both\fold_4
#   device=cuda:0 (NVIDIA GeForce RTX 3060, 8.6 GB)
#   samples: train=1032, val=257, final_test=2192
#   batches: train=16, val=5, test=35
#   max_epochs=100, batch_size=64
# Epoch [1/100] - Val acc: 10.12%
#   New best model saved
# Epoch [2/100] - Val acc: 44.36%
#   New best model saved
# Epoch [3/100] - Val acc: 74.71%
#   New best model saved
# Epoch [4/100] - Val acc: 82.88%
#   New best model saved
# Epoch [5/100] - Val acc: 86.38%
#   New best model saved
# Epoch [6/100] - Val acc: 90.27%
#   New best model saved
# Epoch [7/100] - Val acc: 90.27%
# Epoch [8/100] - Val acc: 90.27%
# Epoch [9/100] - Val acc: 91.44%
#   New best model saved
# Epoch [10/100] - Val acc: 92.22%
#   New best model saved
# Epoch [11/100] - Val acc: 92.22%
# Epoch [12/100] - Val acc: 91.05%
# Epoch [13/100] - Val acc: 91.44%
# Epoch [14/100] - Val acc: 91.83%
# Epoch [15/100] - Val acc: 93.39%
#   New best model saved
# Epoch [16/100] - Val acc: 91.44%
# Epoch [17/100] - Val acc: 92.61%
# Epoch [18/100] - Val acc: 92.22%
# Epoch [19/100] - Val acc: 91.44%
# Epoch [20/100] - Val acc: 92.61%
# Epoch [21/100] - Val acc: 93.00%
# Epoch [22/100] - Val acc: 94.55%
#   New best model saved
# Epoch [23/100] - Val acc: 94.16%
# Epoch [24/100] - Val acc: 93.00%
# Epoch [25/100] - Val acc: 93.39%
# Epoch [26/100] - Val acc: 92.61%
# Epoch [27/100] - Val acc: 93.00%
# Epoch [28/100] - Val acc: 93.00%
# Epoch [29/100] - Val acc: 93.39%
# Epoch [30/100] - Val acc: 92.61%
# Epoch [31/100] - Val acc: 94.16%
# Epoch [32/100] - Val acc: 93.00%
# Epoch [33/100] - Val acc: 91.83%
# Epoch [34/100] - Val acc: 91.44%
# Epoch [35/100] - Val acc: 92.61%
# Epoch [36/100] - Val acc: 93.00%
# Epoch [37/100] - Val acc: 93.00%
# Early stopping triggered.
# c:\Users\solok\Desktop\Dcase baseline\dcase2026_task1_baseline\evaluate.py:97: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# [BaseClassifier | Fold final_test] Accuracy: 57.25%
# [BaseClassifier | Fold final_test] Top class accuracy: 73.86%
# [BaseClassifier | Fold final_test] Macro accuracy: 43.43%
# [BaseClassifier | Fold final_test] Macro top class accuracy: 65.22%
# [BaseClassifier | Fold final_test] Hierarchical accuracy: 54.32%
# [BaseClassifier | Fold final_test] Hierarchical precision: 58.69%
# [BaseClassifier | Fold final_test] Hierarchical recall: 66.64%
# [BaseClassifier | Fold final_test] Hierarchical F1: 61.44%
#   completed in 0.7 min
#   filter_label                score_column  threshold  display_threshold  \
# 0    pred_ge_2  predicted_confidence_score        2.0                  2
# 1    pred_ge_3  predicted_confidence_score        3.0                  3
# 2    pred_ge_4  predicted_confidence_score        4.0                  4
#
#    train_pool_samples  retained_samples  dropped_samples  retained_ratio  \
# 0                8764              8763                1        0.999886
# 1                8764              8155              609        0.930511
# 2                8764              1289             7475        0.147079
#
#    num_classes_retained
# 0                    23
# 1                    23
# 2                    19
#                          experiment filter_label                score_column  \
# 0   517_regression_continuous_score    pred_ge_2  predicted_confidence_score
# 1   517_regression_continuous_score    pred_ge_2  predicted_confidence_score
# 2   517_regression_continuous_score    pred_ge_2  predicted_confidence_score
# 3   517_regression_continuous_score    pred_ge_2  predicted_confidence_score
# 4   517_regression_continuous_score    pred_ge_2  predicted_confidence_score
# 5   517_regression_continuous_score    pred_ge_3  predicted_confidence_score
# 6   517_regression_continuous_score    pred_ge_3  predicted_confidence_score
# 7   517_regression_continuous_score    pred_ge_3  predicted_confidence_score
# 8   517_regression_continuous_score    pred_ge_3  predicted_confidence_score
# 9   517_regression_continuous_score    pred_ge_3  predicted_confidence_score
# 10  517_regression_continuous_score    pred_ge_4  predicted_confidence_score
# 11  517_regression_continuous_score    pred_ge_4  predicted_confidence_score
# 12  517_regression_continuous_score    pred_ge_4  predicted_confidence_score
# 13  517_regression_continuous_score    pred_ge_4  predicted_confidence_score
# 14  517_regression_continuous_score    pred_ge_4  predicted_confidence_score
#
#     threshold  display_threshold  train_pool_samples  retained_samples  \
# 0         2.0                  2                8764              8763
# 1         2.0                  2                8764              8763
# 2         2.0                  2                8764              8763
# 3         2.0                  2                8764              8763
# 4         2.0                  2                8764              8763
# 5         3.0                  3                8764              8155
# 6         3.0                  3                8764              8155
# 7         3.0                  3                8764              8155
# 8         3.0                  3                8764              8155
# 9         3.0                  3                8764              8155
# 10        4.0                  4                8764              1289
# 11        4.0                  4                8764              1289
# 12        4.0                  4                8764              1289
# 13        4.0                  4                8764              1289
# 14        4.0                  4                8764              1289
#
#     retained_ratio  final_test_samples status  ... best_val_accuracy  \
# 0         0.999886                2192     ok  ...         80.604678
# 1         0.999886                2192     ok  ...         80.262407
# 2         0.999886                2192     ok  ...         79.806047
# 3         0.999886                2192     ok  ...         79.965753
# 4         0.999886                2192     ok  ...         79.623288
# 5         0.930511                2192     ok  ...         80.748007
# 6         0.930511                2192     ok  ...         80.380135
# 7         0.930511                2192     ok  ...         81.606376
# 8         0.930511                2192     ok  ...         81.667689
# 9         0.930511                2192     ok  ...         81.790313
# 10        0.147079                2192     ok  ...         91.860465
# 11        0.147079                2192     ok  ...         94.186047
# 12        0.147079                2192     ok  ...         94.186047
# 13        0.147079                2192     ok  ...         93.798450
# 14        0.147079                2192     ok  ...         94.552529
#
#      accuracy  top_accuracy  macro_accuracy  macro_top_accuracy  \
# 0   80.291971     89.370438       73.833666           84.816286
# 1   80.246350     89.005474       74.696170           84.940443
# 2   80.839416     89.142336       75.353190           84.876379
# 3   81.250000     89.507299       75.711294           85.592309
# 4   79.197080     88.093066       71.304289           82.321700
# 5   80.291971     89.826642       74.215347           85.371702
# 6   80.702555     89.233577       74.849110           85.145698
# 7   79.972628     89.233577       74.622485           85.159572
# 8   80.018248     89.370438       73.092354           84.723344
# 9   79.790146     89.461679       73.263426           84.876720
# 10  58.394161     76.414234       44.296195           68.718568
# 11  57.436131     74.315693       42.592543           64.680921
# 12  54.881387     74.589416       39.714127           67.815505
# 13  56.888686     74.863139       43.456733           67.087925
# 14  57.253650     73.859489       43.428954           65.219282
#
#     hierarchical_accuracy  hierarchical_precision  hierarchical_recall  \
# 0               79.324976               79.285289            77.952149
# 1               79.818307               79.647991            78.537773
# 2               80.114784               79.959237            78.924385
# 3               80.651801               80.820224            79.416675
# 4               76.812994               79.435472            75.435818
# 5               79.793524               79.248270            78.398980
# 6               79.997404               79.230426            78.710330
# 7               79.891029               79.902144            78.573893
# 8               78.907849               79.797008            77.453975
# 9               79.070073               79.002568            77.618411
# 10              56.507381               59.269715            68.295633
# 11              53.636732               57.714446            68.390942
# 12              53.764816               60.391329            72.047696
# 13              55.272329               62.463661            72.703491
# 14              54.324118               58.688718            66.638209
#
#     hierarchical_f1                                         output_dir
# 0         78.395820  c:\Users\solok\Desktop\Dcase baseline\baseline...
# 1         78.855344  c:\Users\solok\Desktop\Dcase baseline\baseline...
# 2         79.311229  c:\Users\solok\Desktop\Dcase baseline\baseline...
# 3         79.778602  c:\Users\solok\Desktop\Dcase baseline\baseline...
# 4         76.334154  c:\Users\solok\Desktop\Dcase baseline\baseline...
# 5         78.659954  c:\Users\solok\Desktop\Dcase baseline\baseline...
# 6         78.579734  c:\Users\solok\Desktop\Dcase baseline\baseline...
# 7         78.943931  c:\Users\solok\Desktop\Dcase baseline\baseline...
# 8         77.999206  c:\Users\solok\Desktop\Dcase baseline\baseline...
# 9         77.963078  c:\Users\solok\Desktop\Dcase baseline\baseline...
# 10        61.884381  c:\Users\solok\Desktop\Dcase baseline\baseline...
# 11        62.134173  c:\Users\solok\Desktop\Dcase baseline\baseline...
# 12        64.822128  c:\Users\solok\Desktop\Dcase baseline\baseline...
# 13        66.078455  c:\Users\solok\Desktop\Dcase baseline\baseline...
# 14        61.440330  c:\Users\solok\Desktop\Dcase baseline\baseline...
#
# [15 rows x 24 columns]

# %%
from pathlib import Path
import sys
import importlib

ROOT = Path(r"C:\Users\solok\Desktop\Dcase baseline")
sys.path.insert(0, str(ROOT))

import baseline_confidnce_train.confidence_baseline_common as cbc
importlib.reload(cbc)

all_results, best_folds, fig_path = cbc.show_v2_5class_results(
    output_root=ROOT / 'baseline_confidnce_train' / 'outputs' / '517_regression'
)
display(all_results)
display(best_folds)
fig_path
# Out:
# === All downstream run results ===
# source: C:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\summary_results.csv
# saved view: C:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\all_run_results_view.csv
# filter_label  threshold  retained_samples  retained_ratio mode  split  train_samples  val_samples  final_test_samples  best_val_accuracy  accuracy  top_accuracy  macro_accuracy  hierarchical_accuracy  hierarchical_precision  hierarchical_recall  hierarchical_f1                                                                                                  output_dir
#    pred_ge_2        2.0              8763        0.999886 both fold_3           7011         1752                2192          79.965753 81.250000     89.507299       75.711294              80.651801               80.820224            79.416675        79.778602 c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_2\both\fold_3
#    pred_ge_2        2.0              8763        0.999886 both fold_2           7010         1753                2192          79.806047 80.839416     89.142336       75.353190              80.114784               79.959237            78.924385        79.311229 c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_2\both\fold_2
#    pred_ge_3        3.0              8155        0.930511 both fold_1           6524         1631                2192          80.380135 80.702555     89.233577       74.849110              79.997404               79.230426            78.710330        78.579734 c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_3\both\fold_1
#    pred_ge_3        3.0              8155        0.930511 both fold_2           6524         1631                2192          81.606376 79.972628     89.233577       74.622485              79.891029               79.902144            78.573893        78.943931 c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_3\both\fold_2
#    pred_ge_2        2.0              8763        0.999886 both fold_1           7010         1753                2192          80.262407 80.246350     89.005474       74.696170              79.818307               79.647991            78.537773        78.855344 c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_2\both\fold_1
#    pred_ge_3        3.0              8155        0.930511 both fold_0           6524         1631                2192          80.748007 80.291971     89.826642       74.215347              79.793524               79.248270            78.398980        78.659954 c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_3\both\fold_0
#    pred_ge_2        2.0              8763        0.999886 both fold_0           7010         1753                2192          80.604678 80.291971     89.370438       73.833666              79.324976               79.285289            77.952149        78.395820 c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_2\both\fold_0
#    pred_ge_3        3.0              8155        0.930511 both fold_4           6524         1631                2192          81.790313 79.790146     89.461679       73.263426              79.070073               79.002568            77.618411        77.963078 c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_3\both\fold_4
#    pred_ge_3        3.0              8155        0.930511 both fold_3           6524         1631                2192          81.667689 80.018248     89.370438       73.092354              78.907849               79.797008            77.453975        77.999206 c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_3\both\fold_3
#    pred_ge_2        2.0              8763        0.999886 both fold_4           7011         1752                2192          79.623288 79.197080     88.093066       71.304289              76.812994               79.435472            75.435818        76.334154 c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_2\both\fold_4
#    pred_ge_4        4.0              1289        0.147079 both fold_0           1031          258                2192          91.860465 58.394161     76.414234       44.296195              56.507381               59.269715            68.295633        61.884381 c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_4\both\fold_0
#    pred_ge_4        4.0              1289        0.147079 both fold_3           1031          258                2192          93.798450 56.888686     74.863139       43.456733              55.272329               62.463661            72.703491        66.078455 c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_4\both\fold_3
#    pred_ge_4        4.0              1289        0.147079 both fold_4           1032          257                2192          94.552529 57.253650     73.859489       43.428954              54.324118               58.688718            66.638209        61.440330 c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_4\both\fold_4
#    pred_ge_4        4.0              1289        0.147079 both fold_2           1031          258                2192          94.186047 54.881387     74.589416       39.714127              53.764816               60.391329            72.047696        64.822128 c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_4\both\fold_2
#    pred_ge_4        4.0              1289        0.147079 both fold_1           1031          258                2192          94.186047 57.436131     74.315693       42.592543              53.636732               57.714446            68.390942        62.134173 c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_4\both\fold_1
# === Best folds selected for confusion matrix ===
# filter_label  threshold mode  split  retained_samples  retained_ratio  best_val_accuracy  accuracy  hierarchical_f1                                                                                                  output_dir
#    pred_ge_2        2.0 both fold_3              8763        0.999886          79.965753 81.250000        79.778602 c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_2\both\fold_3
#    pred_ge_3        3.0 both fold_1              8155        0.930511          80.380135 80.702555        78.579734 c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_3\both\fold_1
#    pred_ge_4        4.0 both fold_0              1289        0.147079          91.860465 58.394161        61.884381 c:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\pred_ge_4\both\fold_0
#
# saved best-fold table: C:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\best_folds_by_hierarchical_accuracy.csv
# saved confusion matrix figure: C:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\best_fold_confusion_matrices_by_hierarchical_accuracy.png
# saved individual confusion matrix figures:
#   C:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\best_fold_confusion_matrix_pred_ge_2_both.png
#   C:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\best_fold_confusion_matrix_pred_ge_3_both.png
#   C:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\best_fold_confusion_matrix_pred_ge_4_both.png
#
# === Fold mean ± std by confidence threshold ===
# source: C:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\summary_results.csv
# saved summary: C:\Users\solok\Desktop\Dcase baseline\baseline_confidnce_train\outputs\517_regression\fold_metric_summary_by_confidence.csv
#
# confidence2:
#   accuracy              : 80.36% ± 0.77%
#   hierarchical_accuracy : 79.34% ± 1.49%
#   hierarchical_f1       : 78.54% ± 1.33%
#   hierarchical_precision: 79.83% ± 0.61%
#   hierarchical_recall   : 78.05% ± 1.56%
#   macro_accuracy        : 74.18% ± 1.76%
#   macro_top_accuracy    : 84.51% ± 1.26%
#   top_accuracy          : 89.02% ± 0.56%
#
# confidence3:
#   accuracy              : 80.16% ± 0.35%
#   hierarchical_accuracy : 79.53% ± 0.50%
#   hierarchical_f1       : 78.43% ± 0.43%
#   hierarchical_precision: 79.44% ± 0.39%
#   hierarchical_recall   : 78.15% ± 0.58%
#   macro_accuracy        : 74.01% ± 0.79%
#   macro_top_accuracy    : 85.06% ± 0.26%
#   top_accuracy          : 89.43% ± 0.24%
#
# confidence4:
#   accuracy              : 56.97% ± 1.29%
#   hierarchical_accuracy : 54.70% ± 1.20%
#   hierarchical_f1       : 63.27% ± 2.05%
#   hierarchical_precision: 59.71% ± 1.82%
#   hierarchical_recall   : 69.62% ± 2.62%
#   macro_accuracy        : 42.70% ± 1.77%
#   macro_top_accuracy    : 66.70% ± 1.71%
#   top_accuracy          : 74.81% ± 0.97%
#    filter_label  threshold  retained_samples  retained_ratio  mode   split  \
# 3     pred_ge_2        2.0              8763        0.999886  both  fold_3
# 2     pred_ge_2        2.0              8763        0.999886  both  fold_2
# 6     pred_ge_3        3.0              8155        0.930511  both  fold_1
# 7     pred_ge_3        3.0              8155        0.930511  both  fold_2
# 1     pred_ge_2        2.0              8763        0.999886  both  fold_1
# 5     pred_ge_3        3.0              8155        0.930511  both  fold_0
# 0     pred_ge_2        2.0              8763        0.999886  both  fold_0
# 9     pred_ge_3        3.0              8155        0.930511  both  fold_4
# 8     pred_ge_3        3.0              8155        0.930511  both  fold_3
# 4     pred_ge_2        2.0              8763        0.999886  both  fold_4
# 10    pred_ge_4        4.0              1289        0.147079  both  fold_0
# 13    pred_ge_4        4.0              1289        0.147079  both  fold_3
# 14    pred_ge_4        4.0              1289        0.147079  both  fold_4
# 12    pred_ge_4        4.0              1289        0.147079  both  fold_2
# 11    pred_ge_4        4.0              1289        0.147079  both  fold_1
#
#     train_samples  val_samples  final_test_samples  best_val_accuracy  \
# 3            7011         1752                2192          79.965753
# 2            7010         1753                2192          79.806047
# 6            6524         1631                2192          80.380135
# 7            6524         1631                2192          81.606376
# 1            7010         1753                2192          80.262407
# 5            6524         1631                2192          80.748007
# 0            7010         1753                2192          80.604678
# 9            6524         1631                2192          81.790313
# 8            6524         1631                2192          81.667689
# 4            7011         1752                2192          79.623288
# 10           1031          258                2192          91.860465
# 13           1031          258                2192          93.798450
# 14           1032          257                2192          94.552529
# 12           1031          258                2192          94.186047
# 11           1031          258                2192          94.186047
#
#      accuracy  top_accuracy  macro_accuracy  hierarchical_accuracy  \
# 3   81.250000     89.507299       75.711294              80.651801
# 2   80.839416     89.142336       75.353190              80.114784
# 6   80.702555     89.233577       74.849110              79.997404
# 7   79.972628     89.233577       74.622485              79.891029
# 1   80.246350     89.005474       74.696170              79.818307
# 5   80.291971     89.826642       74.215347              79.793524
# 0   80.291971     89.370438       73.833666              79.324976
# 9   79.790146     89.461679       73.263426              79.070073
# 8   80.018248     89.370438       73.092354              78.907849
# 4   79.197080     88.093066       71.304289              76.812994
# 10  58.394161     76.414234       44.296195              56.507381
# 13  56.888686     74.863139       43.456733              55.272329
# 14  57.253650     73.859489       43.428954              54.324118
# 12  54.881387     74.589416       39.714127              53.764816
# 11  57.436131     74.315693       42.592543              53.636732
#
#     hierarchical_precision  hierarchical_recall  hierarchical_f1  \
# 3                80.820224            79.416675        79.778602
# 2                79.959237            78.924385        79.311229
# 6                79.230426            78.710330        78.579734
# 7                79.902144            78.573893        78.943931
# 1                79.647991            78.537773        78.855344
# 5                79.248270            78.398980        78.659954
# 0                79.285289            77.952149        78.395820
# 9                79.002568            77.618411        77.963078
# 8                79.797008            77.453975        77.999206
# 4                79.435472            75.435818        76.334154
# 10               59.269715            68.295633        61.884381
# 13               62.463661            72.703491        66.078455
# 14               58.688718            66.638209        61.440330
# 12               60.391329            72.047696        64.822128
# 11               57.714446            68.390942        62.134173
#
#                                            output_dir
# 3   c:\Users\solok\Desktop\Dcase baseline\baseline...
# 2   c:\Users\solok\Desktop\Dcase baseline\baseline...
# 6   c:\Users\solok\Desktop\Dcase baseline\baseline...
# 7   c:\Users\solok\Desktop\Dcase baseline\baseline...
# 1   c:\Users\solok\Desktop\Dcase baseline\baseline...
# 5   c:\Users\solok\Desktop\Dcase baseline\baseline...
# 0   c:\Users\solok\Desktop\Dcase baseline\baseline...
# 9   c:\Users\solok\Desktop\Dcase baseline\baseline...
# 8   c:\Users\solok\Desktop\Dcase baseline\baseline...
# 4   c:\Users\solok\Desktop\Dcase baseline\baseline...
# 10  c:\Users\solok\Desktop\Dcase baseline\baseline...
# 13  c:\Users\solok\Desktop\Dcase baseline\baseline...
# 14  c:\Users\solok\Desktop\Dcase baseline\baseline...
# 12  c:\Users\solok\Desktop\Dcase baseline\baseline...
# 11  c:\Users\solok\Desktop\Dcase baseline\baseline...
#                         experiment filter_label                score_column  \
# 0  517_regression_continuous_score    pred_ge_2  predicted_confidence_score
# 1  517_regression_continuous_score    pred_ge_3  predicted_confidence_score
# 2  517_regression_continuous_score    pred_ge_4  predicted_confidence_score
#
#    threshold  display_threshold  train_pool_samples  retained_samples  \
# 0        2.0                  2                8764              8763
# 1        3.0                  3                8764              8155
# 2        4.0                  4                8764              1289
#
#    retained_ratio  final_test_samples status  ...   accuracy top_accuracy  \
# 0        0.999886                2192     ok  ...  81.250000    89.507299
# 1        0.930511                2192     ok  ...  80.702555    89.233577
# 2        0.147079                2192     ok  ...  58.394161    76.414234
#
#    macro_accuracy  macro_top_accuracy  hierarchical_accuracy  \
# 0       75.711294           85.592309              80.651801
# 1       74.849110           85.145698              79.997404
# 2       44.296195           68.718568              56.507381
#
#    hierarchical_precision  hierarchical_recall  hierarchical_f1  \
# 0               80.820224            79.416675        79.778602
# 1               79.230426            78.710330        78.579734
# 2               59.269715            68.295633        61.884381
#
#                                           output_dir  fold_num
# 0  c:\Users\solok\Desktop\Dcase baseline\baseline...       3.0
# 1  c:\Users\solok\Desktop\Dcase baseline\baseline...       1.0
# 2  c:\Users\solok\Desktop\Dcase baseline\baseline...       0.0
#
# [3 rows x 25 columns]
# WindowsPath('C:/Users/solok/Desktop/Dcase baseline/baseline_confidnce_train/outputs/517_regression/best_fold_confusion_matrices_by_hierarchical_accuracy.png')
